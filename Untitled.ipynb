# %%
import pandas as pd
a=pd.Series([10,20,30])

# %%
a
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
det=pd.DataFrame({'name':['sagar','raju','suppu','sushma','narmada'],'age':['21','20','25','23','59'],'height':['6','4.5','5','4','5.5']})

# %%
det
# Out:
#       name age
# 0    sagar  21
# 1     raju  20
# 2    suppu  25
# 3   sushma  23
# 4  narmada  59

# %%
det=pd.DataFrame({'name':['sagar','raju','suppu','sushma','narmada'],'age':['21','20','25','23','59'],'height':['6','4.5','5','4','5.5']})

# %%
det
# Out:
#       name age height
# 0    sagar  21      6
# 1     raju  20    4.5
# 2    suppu  25      5
# 3   sushma  23      4
# 4  narmada  59    5.5

# %%
det
# Out:
#       name age height
# 0    sagar  21      6
# 1     raju  20    4.5
# 2    suppu  25      5
# 3   sushma  23      4
# 4  narmada  59    5.5

# %%
det.head()
# Out:
#       name age height
# 0    sagar  21      6
# 1     raju  20    4.5
# 2    suppu  25      5
# 3   sushma  23      4
# 4  narmada  59    5.5

# %%
det.head
# Out:
# <bound method NDFrame.head of       name age height
# 0    sagar  21      6
# 1     raju  20    4.5
# 2    suppu  25      5
# 3   sushma  23      4
# 4  narmada  59    5.5>

# %%
det.head
# Out:
# <bound method NDFrame.head of       name age height
# 0    sagar  21      6
# 1     raju  20    4.5
# 2    suppu  25      5
# 3   sushma  23      4
# 4  narmada  59    5.5>

# %%
det.iloc[0:2,0:1]
# Out:
#     name
# 0  sagar
# 1   raju

# %%
det.iloc[2:2,0:5]
# Out:
# Empty DataFrame
# Columns: [name, age, height]
# Index: []

# %%
det.iloc[0:4,0:1]
# Out:
#      name
# 0   sagar
# 1    raju
# 2   suppu
# 3  sushma

# %%
det.iloc[0:1,0:3]
# Out:
#     name age height
# 0  sagar  21      6

# %%
det
# Out:
#       name age height
# 0    sagar  21      6
# 1     raju  20    4.5
# 2    suppu  25      5
# 3   sushma  23      4
# 4  narmada  59    5.5

# %%
det
# Out:
#       name age height
# 0    sagar  21      6
# 1     raju  20    4.5
# 2    suppu  25      5
# 3   sushma  23      4
# 4  narmada  59    5.5

# %%
det
# Out:
#       name age height
# 0    sagar  21      6
# 1     raju  20    4.5
# 2    suppu  25      5
# 3   sushma  23      4
# 4  narmada  59    5.5

# %%
a=pd.Series([10,10,20,30,40,50,60,70,80,90,15,65,64,20,46])

# %%
a
# Out:
# 0     10
# 1     10
# 2     20
# 3     30
# 4     40
# 5     50
# 6     60
# 7     70
# 8     80
# 9     90
# 10    15
# 11    65
# 12    64
# 13    20
# 14    46
# dtype: int64

# %%
a.mean()
# Out:
# 44.666666666666664

# %%
a.median()
# Out:
# 46.0

# %%
a.head()
# Out:
# 0    10
# 1    10
# 2    20
# 3    30
# 4    40
# dtype: int64

# %%
a.min()
# Out:
# 10

# %%
a.max()
# Out:
# 90

# %%
a.min()
# Out:
# 10

# %%
def double(s):
    return s*2

# %%
def double_m(s):
    return s*2

# %%
def double(s):
    return s*2;

# %%
def double(s):
    return s*2

# %%
det[['height']].apply(double)
# Out:
#    height
# 0      66
# 1  4.54.5
# 2      55
# 3      44
# 4  5.55.5

# %%
det[['name']].apply(double)
# Out:
#              name
# 0      sagarsagar
# 1        rajuraju
# 2      suppusuppu
# 3    sushmasushma
# 4  narmadanarmada

# %%
det['age'].value_counts()
# Out:
# 21    1
# 20    1
# 25    1
# 23    1
# 59    1
# Name: age, dtype: int64

# %%
det['age'].value_counts()
# Out:
# 21    1
# 20    1
# 25    1
# 23    1
# 59    1
# Name: age, dtype: int64

# %%
det.sort_values(by = 'name')
# Out:
#       name age height
# 4  narmada  59    5.5
# 1     raju  20    4.5
# 0    sagar  21      6
# 2    suppu  25      5
# 3   sushma  23      4

# %%
det.sort_values(by = 'height')
# Out:
#       name age height
# 3   sushma  23      4
# 1     raju  20    4.5
# 2    suppu  25      5
# 4  narmada  59    5.5
# 0    sagar  21      6
